# %% [markdown]
# # Lowlevel TensorFlow Functions
# This notebook tests a rebuild of NetworkBuilder and additional supporting classes that utilize the lower level TensorFlow API (tf.nn) instead of higher level API (tf.contrib.layers).

# %% [markdown]
# ## Initial setup (borrowed from Network Visualization notebook)

# %%
# If using one or multiple GPUs
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %%
import sys
sys.path.insert(0, "../python")
from vizdoom import *
from helper import create_network, create_agent
import tensorflow as tf
# %load_ext autoreload
# %autoreload 2

# %%
# Credit: https://stackoverflow.com/questions/38189119/simple-way-to-visualize-a-tensorflow-graph-in-jupyter/38192374#38192374
from IPython.display import clear_output, Image, display, HTML
import numpy as np

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %% [markdown]
# ## layers.py

# %% [markdown]
# ### On layers branch

# %%
phi = 4
channels= 3
num_actions = 4
learning_rate = 0.00025
params_file_path = None
output_directory = "./lowlevel_tf/"
scope = ""

# %%
tf.reset_default_graph()
sess = tf.Session()
net_file = "../networks/test.json"
network = create_network(net_file,
                         phi=phi, 
                         num_channels=channels, 
                         num_actions=num_actions,
                         learning_rate=learning_rate,
                         params_file=params_file_path,
                         output_directory=output_directory,
                         session=sess,
                         scope=scope)
show_graph(tf.get_default_graph().as_graph_def())
# Out:
# NHWC
# [8, 8, 12, 32]
# NHWC
# [4, 4, 32, 64]
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.0756209712393755&quot;).pbtxt = 'node {\n  name: &quot;target_q&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;actions&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;state&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\010\\000\\000\\000\\010\\000\\000\\000\\014\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.10000000149011612\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/RandomStandardNormal&quot;\n  op: &quot;RandomStandardNormal&quot;\n  input: &quot;CONV_1/random_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;CONV_1/random_normal/RandomStandardNormal&quot;\n  input: &quot;CONV_1/random_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;CONV_1/random_normal/mul&quot;\n  input: &quot;CONV_1/random_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/weights&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 8\n        }\n        dim {\n          size: 8\n        }\n        dim {\n          size: 12\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/weights/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;CONV_1/weights&quot;\n  input: &quot;CONV_1/random_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@CONV_1/weights&quot;\n      }\n    }\n  }\n  attr {\n    key: &quo ...

# %%
agent_file_path = "../agents/test.json"
params_file_path = "./lowlevel_tf/dqn_params/train_model-100"
config_file_path = "../config/linear_track.cfg"
results_dir = "../tmp/tmp_results/"
action_set = "basic_four"

# %% [markdown]
# ### On layers branch

# %%
# Initializes DoomGame from config file
def initialize_vizdoom(config_file):
    print("Initializing doom... ", end=""), sys.stdout.flush()
    game = DoomGame()
    game.load_config(config_file)
    game.set_window_visible(True)
    game.init()
    print("Done.")
    return game

# %%
tf.reset_default_graph()
game = initialize_vizdoom(config_file_path)
agent = create_agent(agent_file_path,
                     game=game, 
                     params_file=params_file_path,
                     action_set=action_set,
                     output_directory=results_dir,
                     train_mode=False)
agent.initialize_new_episode()
current_screen = game.get_state().screen_buffer
agent.update_state(current_screen)
print("Q: ", agent.network.get_q_values(agent.state))
a_best = agent.network.get_best_action(agent.state).item()
print("a_best: ", a_best)
game.close()
# Out:
# Initializing doom... Done.
# NHWC
# [8, 8, 12, 32]
# NHWC
# [4, 4, 32, 64]
# INFO:tensorflow:Restoring parameters from ./lowlevel_tf/dqn_params/train_model-100
# Q:  [[-3.93629551 -3.95156717 -3.94152212 -3.9497273 ]]
# a_best:  0
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.0756209712393755&quot;).pbtxt = 'node {\n  name: &quot;target_q&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;actions&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;state&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\010\\000\\000\\000\\010\\000\\000\\000\\014\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.10000000149011612\n      }\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/RandomStandardNormal&quot;\n  op: &quot;RandomStandardNormal&quot;\n  input: &quot;CONV_1/random_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;CONV_1/random_normal/RandomStandardNormal&quot;\n  input: &quot;CONV_1/random_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/random_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;CONV_1/random_normal/mul&quot;\n  input: &quot;CONV_1/random_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/weights&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 8\n        }\n        dim {\n          size: 8\n        }\n        dim {\n          size: 12\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;CONV_1/weights/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;CONV_1/weights&quot;\n  input: &quot;CONV_1/random_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@CONV_1/weights&quot;\n      }\n    }\n  }\n  attr {\n    key: &quo ...

# %% [markdown]
# ### On develop branch

# %%
phi = 4
channels= 3
num_actions = 4
learning_rate = 0.00025
params_file_path = None
output_directory = "./lowlevel_tf/"
scope = "main_network"

# %%
tf.reset_default_graph()
sess = tf.Session()
net_file = "../networks/test.json"
network = create_network(net_file,
                         phi=phi, 
                         num_channels=channels, 
                         num_actions=num_actions,
                         learning_rate=learning_rate,
                         params_file=params_file_path,
                         output_directory=output_directory,
                         session=sess,
                         scope=scope)
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.6583704438560813&quot;).pbtxt = 'node {\n  name: &quot;main_network/target_q&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/actions&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/state&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/CONV_1/weights/Initializer/random_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@main_network/CONV_1/weights&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\010\\000\\000\\000\\010\\000\\000\\000\\014\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/CONV_1/weights/Initializer/random_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@main_network/CONV_1/weights&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/CONV_1/weights/Initializer/random_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@main_network/CONV_1/weights&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.10000000149011612\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/CONV_1/weights/Initializer/random_normal/RandomStandardNormal&quot;\n  op: &quot;RandomStandardNormal&quot;\n  input: &quot;main_network/CONV_1/weights/Initializer/random_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@main_network/CONV_1/weights&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;main_network/CONV_1/weights/Initializer/random_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;main_network/CONV_1/weights/Initializer/random_normal/RandomStandardNormal&quot;\n  input: &quot;main_network/CONV_1/weights/Initializer/random_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@main_network/CONV_1/weights&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;main_network/CONV_1/weights/Initializer/random_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;main_network/CONV_1/weights/Initializer/random_normal/mul&quot;\n  input: &quot;main_network/CONV_1/weights/Initi ...

# %%
agent_file_path = "../agents/test.json"
params_file_path = "./lowlevel_tf/dqn_params/train_model-100"
config_file_path = "../config/linear_track.cfg"
results_dir = "../tmp/tmp_results/"
action_set = "basic_four"

# %%
# Initializes DoomGame from config file
def initialize_vizdoom(config_file):
    print("Initializing doom... ", end=""), sys.stdout.flush()
    game = DoomGame()
    game.load_config(config_file)
    game.set_window_visible(True)
    game.init()
    print("Done.")
    return game

# %%
tf.reset_default_graph()
game = initialize_vizdoom(config_file_path)
agent = create_agent(agent_file_path,
                     game=game, 
                     params_file=params_file_path,
                     action_set=action_set,
                     output_directory=results_dir,
                     train_mode=False)
agent.initialize_new_episode()
current_screen = game.get_state().screen_buffer
agent.update_state(current_screen)
print("Q: ", agent.network.get_q_values(agent.state))
a_best = agent.network.get_best_action(agent.state).item()
print("a_best: ", a_best)
game.close()
# Out:
# Initializing doom... Done.
# INFO:tensorflow:Restoring parameters from ./lowlevel_tf/dqn_params/train_model-100
# Q:  [[-3.93375802 -3.94898081 -3.93895984 -3.94714355]]
# a_best:  0

# %%
tf.reset_default_graph()
game = initialize_vizdoom(config_file_path)
agent = create_agent(agent_file_path,
                     game=game, 
                     params_file=params_file_path,
                     action_set=action_set,
                     output_directory=results_dir,
                     train_mode=False)
agent.initialize_new_episode()
current_screen = game.get_state().screen_buffer
agent.update_state(current_screen)
print("Q: ", agent.network.get_q_values(agent.state))
print("Q_bias: ", agent.sess.run(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES)[-1]))
a_best = agent.network.get_best_action(agent.state).item()
print("a_best: ", a_best)
game.close()
# Out:
# Initializing doom... Done.
# INFO:tensorflow:Restoring parameters from ./lowlevel_tf/dqn_params/train_model-100
# Q:  [[ 0.  0.  0.  0.]]
# Q_bias:  [-3.08783484 -3.08685422 -3.08485365 -3.08579946]
# a_best:  0

# %% [markdown]
# Calculations appear the same on both branches (with DQN).

# %% [markdown]
# ### Implementing batch norm layer

# %%
phi = 4
channels= 3
num_actions = 4
learning_rate = 0.00025
params_file_path = None
output_directory = "./lowlevel_tf/"
scope = "main_network"

# %%
tf.reset_default_graph()
sess = tf.Session()
net_file = "../networks/test.json"
network = create_network(net_file,
                         phi=phi, 
                         num_channels=channels, 
                         num_actions=num_actions,
                         learning_rate=learning_rate,
                         params_file=params_file_path,
                         output_directory=output_directory,
                         session=sess,
                         scope=scope)
show_graph(tf.get_default_graph().as_graph_def())
# Out:
# Tensor("main_network/CONV_1/convolution:0", shape=(?, 32, 20, 20), dtype=float32)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b53fb83f78a6> in <module>()
#      10                          output_directory=output_directory,
#      11                          session=sess,
# ---> 12                          scope=scope)
#      13 show_graph(tf.get_default_graph().as_graph_def())
#
# ~/DRL/ViZDoom/myvizdoom/python/helper.py in create_network(network_filename, **kwargs)
#      24     net_file = json.loads(open(network_filename).read())
#      25     net_type = net_file["global_features"]["type"].lower()
# ---> 26     return network_types[net_type](network_file=network_filename, **kwargs)
#      27
#      28 def create_memory(memory_type, **kwargs):
#
# ~/DRL/ViZDoom/myvizdoom/python/network/DQNetwork.py in __init__(self, phi, num_channels, num_actions, output_directory, session, train_mode, learning_rate, network_file, params_file, scope)
#      29                          network_file=network_file,
#      30                          params_file=params_file,
# ---> 31                          scope=scope)
#      32
#      33         # Set Q-learning variables
#
# ~/DRL/ViZDoom/myvizdoom/python/network/Network.py in __init__(self, phi, num_channels, num_actions, output_directory, session, train_mode, learning_rate, network_file, params_file, scope)
#      48             self.name = network_file[0:-5]
#      49             builder = NetworkBuilder(self, network_file)
# ---> 50             self.graph_dict, self.data_format = builder.load_json(network_file)
#      51             self.state = self.graph_dict["state"][0]
#      52             self.input_shape = self.state.get_shape().as_list()[1:]
#
# ~/DRL/ViZDoom/myvizdoom/python/network/NetworkBuilder.py in load_json(self, network_file)
#     247                 l = builder_type._add_output_layer(layer)
#     248             else:
# --> 249                 l = self.add_layer(layer)
#     250             self.graph_dict[layer["name"]] = [l, "l"]
#     251
#
# ~/DRL/ViZDoom/myvizdoom/python/network/NetworkBuilder.py in add_layer(self, layer)
#      84         return create_layer(input_layer,
#      85                             layer,
# ---> 86                             data_format=self.data_format)
#      87
#      88     # Adds operation to graph
#
# ~/DRL/ViZDoom/myvizdoom/python/network/layers.py in create_layer(input_layer, layer_dict, data_format)
#       5     if layer_type.lower() == "conv2d":
#       6         layer_dict["kwargs"]["data_format"] = data_format
# ----> 7         return conv2d(input_layer, **layer_dict["kwargs"])
#       8     elif layer_type.lower() == "flatten":
#       9         layer_dict["kwargs"]["data_format"] = data_format
#
# ~/DRL/ViZDoom/myvizdoom/python/network/layers.py in conv2d(input_layer, num_outputs, kernel_size, stride, padding, data_format, normalizer_fn, activation_fn, weights_initializer, biases_initializer, trainable, scope)
#      96         if normalizer_fn is not None:
#      97             norm_type, norm_params = _check_list(normalizer_fn)
# ---> 98             out = _apply_normalization(norm_type, out, *norm_params)
#      99
#     100         # Add biases
#
# ~/DRL/ViZDoom/myvizdoom/python/network/layers.py in _apply_normalization(norm_type, x, *args)
#      41 def _apply_normalization(norm_type, x, *args):
#      42     if norm_type == "batch_norm":
# ---> 43         return batch_norm(x, *args)
#      44
#      45 def _apply_activation(activation_type, x, *args):
#
# ~/DRL/ViZDoom/myvizdoom/python/network/layers.py in batch_norm(x, decay, epsilon, scope)
#     213         # Assume shape [batch_size, ...]
#     214         print(x)
# --> 215         batch_mean, batch_var = tf.nn.moments(x, 0, name="moments")
#     216         x_hat_train = (x - batch_mean) / (tf.sqrt(batch_var + epsilon))
#     217         new_pop_mean = (1 - decay) * batch_mean + decay * pop_mean
#
# ~/anaconda3/envs/vizdoom/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py in moments(x, axes, shift, name, keep_dims)
#     640       shift = math_ops.cast(shift, y.dtype)
#     641     counts, m_ss, v_ss, shift = sufficient_statistics(
# --> 642         y, axes, shift=shift, keep_dims=keep_dims, name=name)
#     643     # Reshape shift as needed.
#     644     shift = array_ops.reshape(shift, array_ops.shape(m_ss))
#
# ~/anaconda3/envs/vizdoom/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py in sufficient_statistics(x, axes, shift, keep_dims, name)
#     542     * the shift by which the mean must be corrected or None if `shift` is None.
#     543   """
# --> 544   axes = list(set(axes))
#     545   with ops.name_scope(name, "sufficient_statistics", [x, shift]):
#     546     x = ops.convert_to_tensor(x, name="x")
#
# TypeError: 'int' object is not iterable
